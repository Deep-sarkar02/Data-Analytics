# %% [markdown]
# #explore pandas df and series

# %%
 # series
import pandas as pd
import numpy as np
data = pd.Series([10 , 20 ,30 ])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# now if we want to extrat any of the element from this
data[1] # pass the index only
# Out:
# np.int64(20)

# %%
# for df we need to pass 2 thing to extract the data
# create the data dictionary
data = {
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Age": [25, 30, 35, 40],
    "City": ["New York", "Los Angeles", "Chicago", "Houston"]
}

# create the DataFrame
df = pd.DataFrame(data)

# display the DataFrame
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
# now to extract this
df.loc[1 , 'City']
# Out:
# 'Los Angeles'

# %% [markdown]
# #multi indexing

# %%
#  create a seride
data = {
    "2024-07-05": 59.60,
    "2023-01-10": 341.15,
    "2024-05-01": 127.21,
    "2024-05-04": 9.66,
    "2024-11-30": 93.61,
    "2023-10-29": 778.35,
    "2023-06-09": 604.25,
    "2024-04-29": 33.53,
    "2023-01-08": 41.58,
    "2023-10-15": 56.13,
    "2024-12-25": 157.56,
    "2023-02-05": 98.04,
    "2024-09-12": 171.59,
    "2023-12-17": 59.49,
    "2023-01-03": 81.30,
    "2023-11-19": 6.54,
    "2023-06-13": 317.31,
    "2023-11-30": 181.28,
    "2023-10-14": 340.30,
    "2025-01-07": 70.93
}

# %%
s = pd.Series(data)
s
# Out:
# 2024-07-05     59.60
# 2023-01-10    341.15
# 2024-05-01    127.21
# 2024-05-04      9.66
# 2024-11-30     93.61
# 2023-10-29    778.35
# 2023-06-09    604.25
# 2024-04-29     33.53
# 2023-01-08     41.58
# 2023-10-15     56.13
# 2024-12-25    157.56
# 2023-02-05     98.04
# 2024-09-12    171.59
# 2023-12-17     59.49
# 2023-01-03     81.30
# 2023-11-19      6.54
# 2023-06-13    317.31
# 2023-11-30    181.28
# 2023-10-14    340.30
# 2025-01-07     70.93
# dtype: float64

# %% [markdown]
# #find sales for particular year , find sales for particular month and year(11 2024) , also find the sales for particular month , year , day
# (11 , 11 ,2024)

# %%
# now convert the index of the series to datetime
s.index = pd.to_datetime(s.index);
s
# Out:
# 2024-07-05     59.60
# 2023-01-10    341.15
# 2024-05-01    127.21
# 2024-05-04      9.66
# 2024-11-30     93.61
# 2023-10-29    778.35
# 2023-06-09    604.25
# 2024-04-29     33.53
# 2023-01-08     41.58
# 2023-10-15     56.13
# 2024-12-25    157.56
# 2023-02-05     98.04
# 2024-09-12    171.59
# 2023-12-17     59.49
# 2023-01-03     81.30
# 2023-11-19      6.54
# 2023-06-13    317.31
# 2023-11-30    181.28
# 2023-10-14    340.30
# 2025-01-07     70.93
# dtype: float64

# %%
#all the sales for 2024
# sort all the date in 2024
s.index.year == 2024
# form the data from thsis
s[s.index.year == 2024]
# Out:
# 2024-07-05     59.60
# 2024-05-01    127.21
# 2024-05-04      9.66
# 2024-11-30     93.61
# 2024-04-29     33.53
# 2024-12-25    157.56
# 2024-09-12    171.59
# dtype: float64

# %%
# Q2 .
# we need sales for the month 11 and yearr 2024
(s.index.year == 2024) & (s.index.month == 11)

# put it into series
s[(s.index.year == 2024) & (s.index.month == 11)]
# Out:
# 2024-11-30    93.61
# dtype: float64

# %% [markdown]
# # now if we make the date and time col in to 3 index 1. date
# #2.year
# #3.month  so we can extract rhe data very easily and our code complexity will also be low

# %%
# copy the original series to new place
m = s.copy()
m
# Out:
# 2024-07-05     59.60
# 2023-01-10    341.15
# 2024-05-01    127.21
# 2024-05-04      9.66
# 2024-11-30     93.61
# 2023-10-29    778.35
# 2023-06-09    604.25
# 2024-04-29     33.53
# 2023-01-08     41.58
# 2023-10-15     56.13
# 2024-12-25    157.56
# 2023-02-05     98.04
# 2024-09-12    171.59
# 2023-12-17     59.49
# 2023-01-03     81.30
# 2023-11-19      6.54
# 2023-06-13    317.31
# 2023-11-30    181.28
# 2023-10-14    340.30
# 2025-01-07     70.93
# dtype: float64

# %%
# now we will create the multiindex
arr = [m.index.year , m.index.month , m.index.day]

# %%
#now use the pd function for multiindexing
pd.MultiIndex.from_arrays(arr , names = ['year' , 'month' , 'day'])
# Out:
# MultiIndex([(2024,  7,  5),
#             (2023,  1, 10),
#             (2024,  5,  1),
#             (2024,  5,  4),
#             (2024, 11, 30),
#             (2023, 10, 29),
#             (2023,  6,  9),
#             (2024,  4, 29),
#             (2023,  1,  8),
#             (2023, 10, 15),
#             (2024, 12, 25),
#             (2023,  2,  5),
#             (2024,  9, 12),
#             (2023, 12, 17),
#             (2023,  1,  3),
#             (2023, 11, 19),
#             (2023,  6, 13),
#             (2023, 11, 30),
#             (2023, 10, 14),
#             (2025,  1,  7)],
#            names=['year', 'month', 'day'])

# %%
# nwo the indedx fo th series will be equal to
m.index = pd.MultiIndex.from_arrays(arr , names = ['year' , 'month' , 'day'])

# %%
m
# Out:
# year  month  day
# 2024  7      5       59.60
# 2023  1      10     341.15
# 2024  5      1      127.21
#              4        9.66
#       11     30      93.61
# 2023  10     29     778.35
#       6      9      604.25
# 2024  4      29      33.53
# 2023  1      8       41.58
#       10     15      56.13
# 2024  12     25     157.56
# 2023  2      5       98.04
# 2024  9      12     171.59
# 2023  12     17      59.49
#       1      3       81.30
#       11     19       6.54
#       6      13     317.31
#       11     30     181.28
#       10     14     340.30
# 2025  1      7       70.93
# dtype: float64

# %%
# now we will completer the qs
# find the sales for the year 2024
m[2024]
# Out:
# month  day
# 7      5       59.60
# 5      1      127.21
#        4        9.66
# 11     30      93.61
# 4      29      33.53
# 12     25     157.56
# 9      12     171.59
# dtype: float64

# %%
# now for 11 month and 2024
m[2024, 11]
# Out:
# /tmp/ipython-input-36-1594787561.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   m[2024, 11]
# day
# 30    93.61
# dtype: float64

# %%
# for 2024 , 11 , 30
m[2024 ,11 , 30]
# Out:
# np.float64(93.61)

# %%
# 2nd way of creating multiindexing

# if i need 2 index one will be year and another will be cat of shopping
# eg : ["electric" , "cloting" , "machinary"]
# now if for each year we need all the values
# so this is the live dot product

# so we will use multiindex from product

mi=pd.MultiIndex.from_product([[2019 , 2020 , 2021 ,2022 ,2023 ,2024] , ["electric" , "cloting" , "machinary" ]])

# %%
mi
# Out:
# MultiIndex([(2019,  'electric'),
#             (2019,   'cloting'),
#             (2019, 'machinary'),
#             (2020,  'electric'),
#             (2020,   'cloting'),
#             (2020, 'machinary'),
#             (2021,  'electric'),
#             (2021,   'cloting'),
#             (2021, 'machinary'),
#             (2022,  'electric'),
#             (2022,   'cloting'),
#             (2022, 'machinary'),
#             (2023,  'electric'),
#             (2023,   'cloting'),
#             (2023, 'machinary'),
#             (2024,  'electric'),
#             (2024,   'cloting'),
#             (2024, 'machinary')],
#            )

# %%
# now we will give random values from 100 to 200 and  indedx will be these valeus
# and makr this a series
# we need 18 valeus since the total value will be 18
s1=pd.Series(np.random.randint(100 , 200 ,18) ,index = mi)
# this will make the random value to the series and the index wil  be the mi

# this is 2d data
# pandas df is a 2d data

# %%
s1
# Out:
# 2019  electric     130
#       cloting      149
#       machinary    160
# 2020  electric     135
#       cloting      131
#       machinary    177
# 2021  electric     143
#       cloting      120
#       machinary    102
# 2022  electric     161
#       cloting      120
#       machinary    178
# 2023  electric     199
#       cloting      101
#       machinary    103
# 2024  electric     118
#       cloting      110
#       machinary    180
# dtype: int64

# %%
# now to connvert it into data frame
l = s1.reset_index()

l
# Out:
#     level_0    level_1    0
# 0      2019   electric  130
# 1      2019    cloting  149
# 2      2019  machinary  160
# 3      2020   electric  135
# 4      2020    cloting  131
# 5      2020  machinary  177
# 6      2021   electric  143
# 7      2021    cloting  120
# 8      2021  machinary  102
# 9      2022   electric  161
# 10     2022    cloting  120
# 11     2022  machinary  178
# 12     2023   electric  199
# 13     2023    cloting  101
# 14     2023  machinary  103
# 15     2024   electric  118
# 16     2024    cloting  110
# 17     2024  machinary  180

# %%
# we can use another function unstack
k = s1.unstack()
k
# Out:
#       cloting  electric  machinary
# 2019      149       130        160
# 2020      131       135        177
# 2021      120       143        102
# 2022      120       161        178
# 2023      101       199        103
# 2024      110       118        180

# %%
#now convert m  to df
m.unstack().unstack()
# Out:
# day    1                                           ...  30                  \
# month  1   2   4       5   6   7   9   10  11  12  ...  1   2   4   5   6
# year                                               ...
# 2023  NaN NaN NaN     NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN
# 2024  NaN NaN NaN  127.21 NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN
# 2025  NaN NaN NaN     NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN
#
# day
# month  7   9   10      11  12
# year
# 2023  NaN NaN NaN  181.28 NaN
# 2024  NaN NaN NaN   93.61 NaN
# 2025  NaN NaN NaN     NaN NaN
#
# [3 rows x 170 columns]

# %% [markdown]
# #multi-indexing dataframe

# %%
mi
# Out:
# MultiIndex([(2019,  'electric'),
#             (2019,   'cloting'),
#             (2019, 'machinary'),
#             (2020,  'electric'),
#             (2020,   'cloting'),
#             (2020, 'machinary'),
#             (2021,  'electric'),
#             (2021,   'cloting'),
#             (2021, 'machinary'),
#             (2022,  'electric'),
#             (2022,   'cloting'),
#             (2022, 'machinary'),
#             (2023,  'electric'),
#             (2023,   'cloting'),
#             (2023, 'machinary'),
#             (2024,  'electric'),
#             (2024,   'cloting'),
#             (2024, 'machinary')],
#            )

# %%
#create a df from the dictionary
df = pd.DataFrame(
    {   # the size must be of length of the mi
        "Sales" : np.random.randint(1000 , 10000 , size = len(mi) ),
        "Quantity"  :np.random.randint(10 , 100 , size = len(mi) )
    }
,index = mi)

# %%
# extract the data of 2019
df.loc[2019]
# Out:
#            Sales  Quantity
# electric    8500        13
# cloting     4203        83
# machinary   3485        69

# %%
# data for 2019 and electric
df.loc[2019 , 'electric'].reset_index()
# Out:
#       index     2019
#             electric
# 0     Sales     8500
# 1  Quantity       13

# %%
df.loc[pd.IndexSlice[2019 , "electric"]]
# Out:
# Sales       8500
# Quantity      13
# Name: (2019, electric), dtype: int64

# %%
# data of electrics
# for the first hiararchy we will omit it
# we need only the 2nd level for all the colm

df.loc[pd.IndexSlice[: , ['electric']] , :]
# Out:
#                Sales  Quantity
# 2019 electric   8500        13
# 2020 electric   7975        64
# 2021 electric   4946        53
# 2022 electric   9195        51
# 2023 electric   7568        27
# 2024 electric   8988        97

# %%
# data of electric and cloting
df.loc[pd.IndexSlice[: , ['electric' , 'cloting']] , :]
# Out:
#                Sales  Quantity
# 2019 electric   8500        13
# 2020 electric   7975        64
# 2021 electric   4946        53
# 2022 electric   9195        51
# 2023 electric   7568        27
# 2024 electric   8988        97
# 2019 cloting    4203        83
# 2020 cloting    9488        29
# 2021 cloting    8374        36
# 2022 cloting    1096        33
# 2023 cloting    3850        95
# 2024 cloting    7440        57

# %%
#need the same data for the year 19 and 24
df.loc[pd.IndexSlice[[2019 , 2024] , ['electric','cloting']] , :]
# Out:
#                Sales  Quantity
# 2019 electric   8500        13
#      cloting    4203        83
# 2024 electric   8988        97
#      cloting    7440        57

# %%
#need the sales of 2019 and 2024
df.loc[pd.IndexSlice[[2019 , 2024] , :] , ['Sales']]
# Out:
#                 Sales
# 2019 electric    8500
#      cloting     4203
#      machinary   3485
# 2024 electric    8988
#      cloting     7440
#      machinary   5477

# %%
m
# Out:
# year  month  day
# 2024  7      5       59.60
# 2023  1      10     341.15
# 2024  5      1      127.21
#              4        9.66
#       11     30      93.61
# 2023  10     29     778.35
#       6      9      604.25
# 2024  4      29      33.53
# 2023  1      8       41.58
#       10     15      56.13
# 2024  12     25     157.56
# 2023  2      5       98.04
# 2024  9      12     171.59
# 2023  12     17      59.49
#       1      3       81.30
#       11     19       6.54
#       6      13     317.31
#       11     30     181.28
#       10     14     340.30
# 2025  1      7       70.93
# dtype: float64

# %%
# value for 7 th month and 2024
m[pd.IndexSlice[2024, 7]]
# Out:
# /tmp/ipython-input-87-600948494.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   m[pd.IndexSlice[2024, 7]]
# day
# 5    59.6
# dtype: float64

# %%
# value for 7 th and 11 month of the 2024
m[pd.IndexSlice[2024 , [ 7 , 12 ]]]
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipython-input-96-4093697548.py in <cell line: 0>()
#       1 # value for 7 th and 11 month of the 2024
# ----> 2 m[pd.IndexSlice[2024 , [ 7 , 12 ]]]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1151             return self._get_rows_with_mask(key)
#    1152
# -> 1153         return self._get_with(key)
#    1154
#    1155     def _get_with(self, key):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _get_with(self, key)
#    1161             )
#    1162         elif isinstance(key, tuple):
# -> 1163             return self._get_values_tuple(key)
#    1164
#    1165         elif not is_list_like(key):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _get_values_tuple(self, key)
#    1208
# ...

# %% [markdown]
# #muliindexing in colms

# %%
mc= pd.MultiIndex.from_product([ ['Delhi' , 'Mumbai'] , ['Sales' , 'Quantity'] ]
                       ,names = ['City' , 'Metric'])
mc
# Out:
# MultiIndex([( 'Delhi',    'Sales'),
#             ( 'Delhi', 'Quantity'),
#             ('Mumbai',    'Sales'),
#             ('Mumbai', 'Quantity')],
#            names=['City', 'Metric'])

# %%
 # we will create a df
 # from is mc
 df1 = pd.DataFrame(index = mi  , columns=mc)

# %%
df1
# Out:
# City           Delhi          Mumbai
# Metric         Sales Quantity  Sales Quantity
# 2019 electric    NaN      NaN    NaN      NaN
#      cloting     NaN      NaN    NaN      NaN
#      machinary   NaN      NaN    NaN      NaN
# 2020 electric    NaN      NaN    NaN      NaN
#      cloting     NaN      NaN    NaN      NaN
#      machinary   NaN      NaN    NaN      NaN
# 2021 electric    NaN      NaN    NaN      NaN
#      cloting     NaN      NaN    NaN      NaN
#      machinary   NaN      NaN    NaN      NaN
# 2022 electric    NaN      NaN    NaN      NaN
#      cloting     NaN      NaN    NaN      NaN
#      machinary   NaN      NaN    NaN      NaN
# 2023 electric    NaN      NaN    NaN      NaN
#      cloting     NaN      NaN    NaN      NaN
#      machinary   NaN      NaN    NaN      NaN
# 2024 electric    NaN      NaN    NaN      NaN
#      cloting     NaN      NaN    NaN      NaN
#      machinary   NaN      NaN    NaN      NaN

# %%
# we will create a dictionary fo the values
# on the sales and the quantity
data = {
    ('Delhi', 'Sales'): np.random.randint(1000, 10000, size=len(mi)),
    ('Delhi', 'Quantity'): np.random.randint(10, 100, size=len(mi)),
    ('Mumbai', 'Sales'): np.random.randint(1000, 10000, size=len(mi)),
    ('Mumbai', 'Quantity'): np.random.randint(10, 100, size=len(mi))
}

data
# Out:
# {('Delhi',
#   'Sales'): array([2131, 2979, 2334, 9913, 2377, 5523, 6984, 4752, 1113, 3625, 6831,
#         2580, 7931, 5425, 3204, 1906, 9935, 5734]),
#  ('Delhi',
#   'Quantity'): array([82, 34, 72, 15, 20, 53, 94, 12, 22, 57, 44, 24, 85, 91, 73, 21, 69,
#         35]),
#  ('Mumbai',
#   'Sales'): array([4945, 9520, 4797, 8750, 1710, 8725, 5410, 4584, 9442, 8123, 7264,
#         3827, 7202, 5676, 8815, 7860, 9912, 8555]),
#  ('Mumbai',
#   'Quantity'): array([14, 39, 82, 44, 77, 98, 28, 52, 10, 46, 83, 39, 20, 71, 31, 99, 89,
#         42])}

# %%
# now we will load the value to the df1
for col , val in data.items():
  df1[col] = val

# %%
df1
# Out:
# City           Delhi          Mumbai
# Metric         Sales Quantity  Sales Quantity
# 2019 electric   2131       82   4945       14
#      cloting    2979       34   9520       39
#      machinary  2334       72   4797       82
# 2020 electric   9913       15   8750       44
#      cloting    2377       20   1710       77
#      machinary  5523       53   8725       98
# 2021 electric   6984       94   5410       28
#      cloting    4752       12   4584       52
#      machinary  1113       22   9442       10
# 2022 electric   3625       57   8123       46
#      cloting    6831       44   7264       83
#      machinary  2580       24   3827       39
# 2023 electric   7931       85   7202       20
#      cloting    5425       91   5676       71
#      machinary  3204       73   8815       31
# 2024 electric   1906       21   7860       99
#      cloting    9935       69   9912       89
#      machinary  5734       35   8555       42

# %%
# now apply all the op of the df
df1.head()

df1.tail()


# sample
df1.sample(6)
# Out:
# City           Delhi          Mumbai
# Metric         Sales Quantity  Sales Quantity
# 2020 cloting    2377       20   1710       77
# 2019 cloting    2979       34   9520       39
# 2021 electric   6984       94   5410       28
# 2024 electric   1906       21   7860       99
# 2021 cloting    4752       12   4584       52
#      machinary  1113       22   9442       10

# %%
# describe
df1.describe()
# Out:
# City          Delhi                  Mumbai
# Metric        Sales   Quantity        Sales   Quantity
# count     18.000000  18.000000    18.000000  18.000000
# mean    4737.611111  50.166667  6950.944444  53.555556
# std     2724.011491  28.372004  2324.526403  28.987263
# min     1113.000000  12.000000  1710.000000  10.000000
# 25%     2427.750000  22.500000  5061.250000  33.000000
# 50%     4188.500000  48.500000  7562.000000  45.000000
# 75%     6556.750000  72.750000  8743.750000  80.750000
# max     9935.000000  94.000000  9912.000000  99.000000

# %%
# info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 18 entries, (np.int64(2019), 'electric') to (np.int64(2024), 'machinary')
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Delhi, Sales)      18 non-null     int64
#  1   (Delhi, Quantity)   18 non-null     int64
#  2   (Mumbai, Sales)     18 non-null     int64
#  3   (Mumbai, Quantity)  18 non-null     int64
# dtypes: int64(4)
# memory usage: 1.5+ KB

# %%
# shape
df1.shape
# Out:
# (18, 4)

# %%
# null
df1.isnull().sum()
# Out:
# City    Metric
# Delhi   Sales       0
#         Quantity    0
# Mumbai  Sales       0
#         Quantity    0
# dtype: int64

# %%
# duplicates
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
# now it is a 4d data
# now extract any data

df1.loc[2019]

# for the data of 2019 and 2022

df1.loc[pd.IndexSlice[[2019 , 2022] , :] ,:]


# only delhi data for the above case
df1.loc[pd.IndexSlice[[2019 , 2022] , : ] ,'Delhi']

# only pick the sales data for all the locatiion
df1.loc[: , pd.IndexSlice[: ,"Sales" ]]



# data fo 2019 and delhi
df1.loc[pd.IndexSlice[2019] , pd.IndexSlice['Delhi']]



# extract the sales colm only
df1.loc[: ,pd.IndexSlice[: , 'Sales'] ]
# Out:
# City           Delhi Mumbai
# Metric         Sales  Sales
# 2019 electric   2131   4945
#      cloting    2979   9520
#      machinary  2334   4797
# 2020 electric   9913   8750
#      cloting    2377   1710
#      machinary  5523   8725
# 2021 electric   6984   5410
#      cloting    4752   4584
#      machinary  1113   9442
# 2022 electric   3625   8123
#      cloting    6831   7264
#      machinary  2580   3827
# 2023 electric   7931   7202
#      cloting    5425   5676
#      machinary  3204   8815
# 2024 electric   1906   7860
#      cloting    9935   9912
#      machinary  5734   8555

# %% [markdown]
# #stacking and unstacking

# %%
# now the innermost heirarchy in the row will
# become the innermost of the colm
df1.unstack()
# again if we call the same thing will happen
df1.unstack().unstack()

# now no heairachy in row
# onlly in the colm it is there
# so otu data is a series

# but if we apply stack on it we will get an error
# since the stack can be applied over the df not on the stack
# Out:
# City    Metric
# Delhi   Sales     cloting    2019    2979
#                              2020    2377
#                              2021    4752
#                              2022    6831
#                              2023    5425
#                                      ...
# Mumbai  Quantity  machinary  2020      98
#                              2021      10
#                              2022      39
#                              2023      31
#                              2024      42
# Length: 72, dtype: int64

# %%
# use stack function
# it will pick the innermost colm and make it the innermost row
df1.unstack().stack()
# Out:
# /tmp/ipython-input-150-438903479.py:3: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df1.unstack().stack()
# City           Delhi          Mumbai
# Metric         Sales Quantity  Sales Quantity
# 2019 cloting    2979       34   9520       39
#      electric   2131       82   4945       14
#      machinary  2334       72   4797       82
# 2020 cloting    2377       20   1710       77
#      electric   9913       15   8750       44
#      machinary  5523       53   8725       98
# 2021 cloting    4752       12   4584       52
#      electric   6984       94   5410       28
#      machinary  1113       22   9442       10
# 2022 cloting    6831       44   7264       83
#      electric   3625       57   8123       46
#      machinary  2580       24   3827       39
# ...

# %%
# tanspose
df1.transpose()
# Out:
#                     2019                       2020                    \
#                 electric cloting machinary electric cloting machinary
# City   Metric
# Delhi  Sales        2131    2979      2334     9913    2377      5523
#        Quantity       82      34        72       15      20        53
# Mumbai Sales        4945    9520      4797     8750    1710      8725
#        Quantity       14      39        82       44      77        98
#
#                     2021                       2022                    \
#                 electric cloting machinary electric cloting machinary
# City   Metric
# Delhi  Sales        6984    4752      1113     3625    6831      2580
#        Quantity       94      12        22       57      44        24
# Mumbai Sales        5410    4584      9442     8123    7264      3827
#        Quantity       28      52        10       46      83        39
#
#                     2023                       2024
# ...

# %%
# to print all the data from
pd.set_option("display.max_columns" , None)
df1.transpose()
# Out:
#                     2019                       2020                    \
#                 electric cloting machinary electric cloting machinary
# City   Metric
# Delhi  Sales        2131    2979      2334     9913    2377      5523
#        Quantity       82      34        72       15      20        53
# Mumbai Sales        4945    9520      4797     8750    1710      8725
#        Quantity       14      39        82       44      77        98
#
#                     2021                       2022                    \
#                 electric cloting machinary electric cloting machinary
# City   Metric
# Delhi  Sales        6984    4752      1113     3625    6831      2580
#        Quantity       94      12        22       57      44        24
# Mumbai Sales        5410    4584      9442     8123    7264      3827
#        Quantity       28      52        10       46      83        39
#
#                     2023                       2024
# ...
